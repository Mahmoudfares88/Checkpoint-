# %%
#importing packages
import requests
import csv
from bs4 import BeautifulSoup

# %%
link = requests.get("https://www.nike.com/w/mens-shoes-6xge1zaof4znik1zy7ok?sort=priceAsc")
src = link.content
soup = BeautifulSoup(src , "lxml")
shoes_name = soup.find_all()

# %%
import requests
from bs4 import BeautifulSoup

def get_html_content(url):
    """
    Returns the HTML content of a Wikipedia page given its URL.
    """
    response = requests.get(url)
    return response.content
    """
    Extracts the title of a Wikipedia article from its HTML content.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    title = soup.find('h1', {'id': 'firstHeading'}).text
    return title

    """
    Extracts the text of a Wikipedia article from its HTML content.
    Returns a dictionary mapping headings to their respective paragraphs.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    paragraphs = soup.find_all('p')
    text_dict = {}
    current_heading = None
    for p in paragraphs:
        if p.find('span', {'class': 'mw-headline'}):
            current_heading = p.find('span', {'class': 'mw-headline'}).text
            text_dict[current_heading] = []
        if current_heading:
            text_dict[current_heading].append(p.text)
    return text_dict

# %%
get_html_content('https://en.wikipedia.org/wiki/FC_Barcelona')
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>FC Barcelona - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwcli
# ...

# %%
headings = []
article_title = []
article_text=[]
paragr =[]
for i in range(len(soup)):
    headings.append(current_heading[i].text)
    article_title.append(title[i].text)
    article_text.append(text_dict[i].text)
print(headings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34912\2487510743.py in <module>
#       4 paragr =[]
#       5 for i in range(len(soup)):
# ----> 6     headings.append(current_heading[i].text)
#       7     article_title.append(title[i].text)
#       8     article_text.append(text_dict[i].text)
#
# NameError: name 'current_heading' is not defined
